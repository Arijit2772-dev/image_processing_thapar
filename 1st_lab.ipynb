# %% [markdown]
# <a href="https://colab.research.google.com/github/biggy27/image_processing/blob/main/1st_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/demo_image.jpeg")
print(img)
# Out:
# [[[252 252 252]
#   [254 254 254]
#   [255 255 255]
#   ...
#   [253 253 253]
#   [255 255 255]
#   [255 255 255]]
#
#  [[247 247 247]
#   [249 249 249]
#   [252 252 252]
#   ...
#   [249 249 249]
#   [251 251 251]
#   [254 254 254]]
#
#  [[242 242 242]
#   [244 244 244]
#   [247 247 247]
#   ...
#   [253 253 253]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[247 247 247]
#   [247 247 247]
#   [248 248 248]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[250 250 250]
#   [250 250 250]
#   [250 250 250]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]
#
#  [[254 254 254]
#   [254 254 254]
#   [255 255 255]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# cv2.imshow # if local browser becasue new browser image..

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=279x181>

# %%
img.shape
# Out:
# (181, 279, 3)

# %% [markdown]
# color image read.. r,g,b channel = .. h,w,ch...

# %%
h,w = img.shape[:2]

# %% [markdown]
# # 2 ku exclude

# %%
print(h,w)
# Out:
# 181 279

# %%
print("height = {}, width = {}".format(h,w))
# Out:
# height = 181, width = 279

# %%
b = img[100,100,0]

# %%
print("b= {}".format(b))
# Out:
# b= 2

# %%
g = img[100,100,1]

# %%
r = img[100,100,2]

# %%
print(b,g,r)
# Out:
# 2 2 2

# %% [markdown]
# cv2tcolor image  , kunsa se kuanse ... bgr-->rgb...  or bgr -->grey... show , write...

# %%
gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(gray_image)
# Out:
# [[252 254 255 ... 253 255 255]
#  [247 249 252 ... 249 251 254]
#  [242 244 247 ... 253 255 255]
#  ...
#  [247 247 248 ... 254 255 255]
#  [250 250 250 ... 254 255 255]
#  [254 254 255 ... 254 255 255]]

# %%
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=279x181>

# %%
gray_image.shape
# Out:
# (181, 279)

# %% [markdown]
# grayscale to binary
# mean value...
# thrreshold see niche 0 usse upar 1/255

# %%
mean_image = np.mean(gray_image)
